# %%
# !pip install -i pandas
# !pip install -i nibabel
# !pip install -i matplotlib    
# !pip install -i transformations
# !pip install -i scikit-learn

# %%
import pandas as pd
import os
import scipy.ndimage as nd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
import math
import sys
from tensorflow.keras.models import load_model
import random
import glob
import nibabel as nib
from collections import defaultdict
from tensorflow.keras.optimizers import Adam, SGD,Adagrad
from tensorflow.compat.v1 import reset_default_graph
from sklearn.model_selection import KFold
from DataLoader import dataGenerator,getIcelandicData,getIXIData,getUKBData
from Util import plotData,getPredictions,loadMR,loadHeader,calculateMeanImg
from ResNet import generateAgePredictionResNet
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping 
from tensorflow.python.keras import backend as K
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from tensorflow.keras.models import load_model
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/compat/v2_compat.py:88: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# !nvidia-smi
# Out:
# Tue Jul  7 16:26:13 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 440.64.00    CUDA Version: 10.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:5E:00.0 Off |                    0 |
# | N/A   26C    P0    31W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
# |   1  Tesla P100-PCIE...  Off  | 00000000:86:00.0 Off |                    0 |
# | N/A   27C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# #### Load data

# %%
imageType = 'GrayMatter'
iceData = getIcelandicData(imageType)

pns = iceData['PN'].unique()
pnTrainingSet, pnTest = train_test_split(pns, test_size = 0.2,random_state=45346)
pnTrain, pnVal = train_test_split(pnTrainingSet, test_size = 0.2,random_state=257572)

train = iceData[iceData['PN'].isin(pnTrain)]
test = iceData[iceData['PN'].isin(pnTest)]
val = iceData[iceData['PN'].isin(pnVal)]

train_IXI,val_IXI = getIXIData(imageType)

# %%
train.Age.hist(bins=25,label='Train')
test.Age.hist(bins=25,label='Test')
val.Age.hist(bins=25,label='Validation')
plt.xlabel('Age')
plt.ylabel('Nr of images')
plt.legend()
plt.show()

# %%
dataShape = (121, 145, 121)

# %%
#meanTrainingAge = train['Age'].mean()

# %%
icelandicMeanImg = calculateMeanImg(train.Loc.values)
# Out:
# 0 done
# 250 done
# 500 done
# 750 done

# %%
batchExample = dataGenerator([train.Loc.values,train.Scanner.values,train.Gender.values],train.Age.values, batch_size = 4, meanImg=None,dim=dataShape,shuffle=False,augment=False,maxAngle=40,maxShift=10)
tmp = batchExample.__getitem__(70)
print('Age: {} years'.format(tmp[1][0][0]))
plotData(tmp[0][0][:,:,:,:,:],c=2,d=10,nSlices=8)

# %% [markdown]
# #### Training

# %%
nEpochs=500
batchSize = 4
steps_per_epoch= train.shape[0]//batchSize
validation_steps = val.shape[0]//batchSize

# %%
default_parameters = [0.001,1e-6,'RawImg','IncludeGender','IncludeScanner',0.00005,0.2,40,10]
lr, decayRate, meanImg, gender, scanner,regAmount, dropRate, maxAngle,maxShift = default_parameters
if gender == 'RandomInput':
    gender_train = np.random.rand(train.Gender.shape[0])
    gender_val = np.random.rand(val.Gender.shape[0])
else:
    gender_train = train.Gender.values
    gender_val = val.Gender.values
if scanner == 'RandomInput':
    scanner_train = np.random.rand(train.Scanner.shape[0])
    scanner_val = np.random.rand(val.Scanner.shape[0])
else:
    scanner_train = train.Scanner.values
    scanner_val = val.Scanner.values
if meanImg == 'SubtractMean':
    meanImg = icelandicMeanImg
else:
    meanImg = None

# %%
model = generateAgePredictionResNet(dataShape,regAmount=regAmount,dropRate=dropRate)
#lr=0.001
#decayRate=1e-6
#momentum=0.9
adam = Adam(lr=lr, decay=decayRate)
model.compile(loss='mean_absolute_error',optimizer=adam, metrics=['mae','mse'])

# %%
mc = ModelCheckpoint('../Models/BrainAgeResNet({}-Ice)'.format(imageType),verbose=1,mode='min',save_best_only=True)
early = EarlyStopping(patience=100, verbose=1)

# %%
h = model.fit(dataGenerator([train.Loc.values,scanner_train,gender_train],train.Age.values, batch_size = batchSize, meanImg=meanImg,dim=dataShape,shuffle=True,augment=True,maxAngle=maxAngle,maxShift=maxShift),
                        validation_data=dataGenerator([val.Loc.values,scanner_val,gender_val],val.Age.values, batch_size = batchSize, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        validation_steps=validation_steps,
                        steps_per_epoch=steps_per_epoch, 
                        epochs=nEpochs,
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        callbacks=[mc,early]
                           )

# %%
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('ResNet Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

plt.show()

plt.plot(h.history['mean_absolute_error'])
plt.plot(h.history['val_mean_absolute_error'])
plt.title('ResNet MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

plt.show()

# %%
model.save('../Models/BrainAgeResNet({}-Ice-TrainedFor{}Epochs)'.format(imageType,len(h.history['loss'])))

# %%
model = load_model('../Models/BrainAgeResNet({}-Ice)'.format(imageType))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
val_prediction = model.predict(dataGenerator([val.Loc.values,scanner_val,gender_val],val.Age.values, batch_size = 1, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        )

test_prediction = model.predict(dataGenerator([test.Loc.values,test.Scanner.values,test.Gender.values],test.Age.values, batch_size = 1, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False
                        )
# Out:
# 296/296 [==============================] - 9s 31ms/step
# 358/358 [==============================] - 37s 103ms/step

# %%
predictions = val_prediction[:,0]
yVal = val.Age.values
print('Validation R^2: ',r2_score(yVal,predictions))
print('Validation MAE: ',mean_absolute_error(yVal,predictions))
y_range = np.arange(np.min(yVal),np.max(yVal))
plt.scatter(yVal,predictions,label='T1 Prediction')
plt.plot(y_range,y_range,c='black',ls='dashed',label='45 deg line')
plt.xlabel('Age')
plt.ylabel('Predicted Age')
plt.legend()
plt.show()

predictions = test_prediction[:,0]
yTest = test.Age.values

print('Test R^2: ',r2_score(yTest,predictions))
print('Test MAE: ',mean_absolute_error(yTest,predictions))
y_range = np.arange(np.min(yTest),np.max(yTest))
plt.scatter(yTest,predictions,label='T1 prediction')
plt.plot(y_range,y_range,c='black',ls='dashed',label='45 deg line')
plt.xlabel('Age')
plt.ylabel('Predicted Age')
plt.legend()
plt.show()
# Out:
# Validation R^2:  0.7196718781385278
# Validation MAE:  4.673956568176682
# Test R^2:  0.7193893399789004
# Test MAE:  4.822677740171635

# %% [markdown]
# #### Transfer learning on IXI

# %%
ixiMeanImg = calculateMeanImg(train_IXI.Loc.values)
# Out:
# 0 done
# 250 done

# %%
train_IXI.Age.hist(bins=25,label='Train')
val_IXI.Age.hist(bins=25,label='Validation')
plt.xlabel('Age')
plt.ylabel('Nr of images')
plt.legend()
plt.show()

# %%
meanImg = None

# %%
batchExample = dataGenerator([train_IXI.Loc.values,train_IXI.Scanner.values,train_IXI.Gender.values],train_IXI.Age.values, batch_size = 4, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False,maxAngle=40,maxShift=10)
tmp = batchExample.__getitem__(70)
print('Age: {} years'.format(tmp[1][0][0]))
plotData(tmp[0][0][:,:,:,:,:],c=2,d=10,nSlices=8)
# Out:
# Age: 29.82 years

# %%
model = load_model('../Models/BrainAgeResNet({}-Ice)'.format(imageType))

for layer in model.layers[:19]:
    layer.trainable = False

adam = Adam(lr=0.001, decay=1e-6)
model.compile(loss='mean_absolute_error',optimizer=adam,metrics=['mae','mse'])

batchSize = 4
    
steps_per_epoch= train_IXI.shape[0]//batchSize
validation_steps = val_IXI.shape[0]//batchSize
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
nEpochs=250
mc = ModelCheckpoint('../Models/BrainAgeResNet({}-Ice-TransferLearningOnIXI)'.format(imageType),verbose=1,mode='min',save_best_only=True)
early = EarlyStopping(patience=100, verbose=1)

# %%
h = model.fit(dataGenerator([train_IXI.Loc.values,train_IXI.Scanner.values,train_IXI.Gender.values],train_IXI.Age.values, batch_size = batchSize, meanImg=meanImg,dim=dataShape,shuffle=True,augment=True,maxAngle=maxAngle,maxShift=maxShift),
                        validation_data=dataGenerator([val_IXI.Loc.values,val_IXI.Scanner.values,val_IXI.Gender.values],val_IXI.Age.values, batch_size = batchSize, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        validation_steps=validation_steps,
                        steps_per_epoch=steps_per_epoch, 
                        epochs=nEpochs,
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        callbacks=[mc,early]
                           )
# Out:
# Epoch 1/250
# 102/103 [============================>.] - ETA: 0s - loss: 7.1796 - mean_absolute_error: 6.8843 - mean_squared_error: 71.7323Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 9.4676 - mean_absolute_error: 9.1730 - mean_squared_error: 135.3745
# Epoch 00001: val_loss improved from inf to 9.46759, saving model to ../Models/BrainAgeResNet(GrayMatter-Ice-TransferLearningOnIXI)
# 103/103 [==============================] - 73s 709ms/step - loss: 7.1563 - mean_absolute_error: 6.8610 - mean_squared_error: 71.2717 - val_loss: 9.4676 - val_mean_absolute_error: 9.1730 - val_mean_squared_error: 135.3745
# Epoch 2/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.4274 - mean_absolute_error: 6.1332 - mean_squared_error: 59.1029Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 7.3838 - mean_absolute_error: 7.0899 - mean_squared_error: 81.6744
# Epoch 00002: val_loss improved from 9.46759 to 7.38385, saving model to ../Models/BrainAgeResNet(GrayMatter-Ice-TransferLearningOnIXI)
# 103/103 [==============================] - 52s 502ms/step - loss: 6.4510 - mean_absolute_error: 6.1567 - mean_squared_error: 59.8619 - val_loss: 7.3838 - val_mean_absolute_error: 7.0899 - val_mean_squared_error: 81.6744
# Epoch 3/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.4060 - mean_absolute_error: 6.1114 - mean_squared_error: 56.7533Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 20.9576 - mean_absolute_error: 20.6629 - mean_squared_error: 481.8945
# Epoch 00003: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 516ms/step - loss: 6.4324 - mean_absolute_error: 6.1378 - mean_squared_error: 58.0513 - val_loss: 20.9576 - val_mean_absolute_error: 20.6629 - val_mean_squared_error: 481.8945
# Epoch 4/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.2563 - mean_absolute_error: 5.9614 - mean_squared_error: 55.7414Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 27.8899 - mean_absolute_error: 27.5948 - mean_squared_error: 831.1415
# Epoch 00004: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 510ms/step - loss: 6.2298 - mean_absolute_error: 5.9349 - mean_squared_error: 55.4088 - val_loss: 27.8899 - val_mean_absolute_error: 27.5948 - val_mean_squared_error: 831.1415
# Epoch 5/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.0408 - mean_absolute_error: 5.7455 - mean_squared_error: 53.2417Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 30.7897 - mean_absolute_error: 30.4934 - mean_squared_error: 989.5634
# Epoch 00005: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 6.0693 - mean_absolute_error: 5.7739 - mean_squared_error: 53.5158 - val_loss: 30.7897 - val_mean_absolute_error: 30.4934 - val_mean_squared_error: 989.5634
# Epoch 6/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.0141 - mean_absolute_error: 5.7167 - mean_squared_error: 50.4612Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 30.7734 - mean_absolute_error: 30.4755 - mean_squared_error: 987.4576
# Epoch 00006: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 519ms/step - loss: 6.0130 - mean_absolute_error: 5.7156 - mean_squared_error: 50.4463 - val_loss: 30.7734 - val_mean_absolute_error: 30.4755 - val_mean_squared_error: 987.4576
# Epoch 7/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.2616 - mean_absolute_error: 5.9632 - mean_squared_error: 54.8988Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 24.3428 - mean_absolute_error: 24.0439 - mean_squared_error: 632.0781
# Epoch 00007: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 6.2447 - mean_absolute_error: 5.9464 - mean_squared_error: 54.5455 - val_loss: 24.3428 - val_mean_absolute_error: 24.0439 - val_mean_squared_error: 632.0781
# Epoch 8/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.0917 - mean_absolute_error: 5.7920 - mean_squared_error: 52.4796Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.0641 - mean_absolute_error: 21.7635 - mean_squared_error: 528.7501
# Epoch 00008: val_loss did not improve from 7.38385
# 103/103 [==============================] - 52s 509ms/step - loss: 6.1102 - mean_absolute_error: 5.8105 - mean_squared_error: 52.7353 - val_loss: 22.0641 - val_mean_absolute_error: 21.7635 - val_mean_squared_error: 528.7501
# Epoch 9/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.9820 - mean_absolute_error: 5.6812 - mean_squared_error: 49.7736Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 25.0294 - mean_absolute_error: 24.7283 - mean_squared_error: 667.9167
# Epoch 00009: val_loss did not improve from 7.38385
# 103/103 [==============================] - 56s 542ms/step - loss: 5.9689 - mean_absolute_error: 5.6681 - mean_squared_error: 49.4852 - val_loss: 25.0294 - val_mean_absolute_error: 24.7283 - val_mean_squared_error: 667.9167
# Epoch 10/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.9012 - mean_absolute_error: 5.6001 - mean_squared_error: 50.2457Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.9773 - mean_absolute_error: 21.6756 - mean_squared_error: 520.9788
# Epoch 00010: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 538ms/step - loss: 5.9094 - mean_absolute_error: 5.6082 - mean_squared_error: 50.1894 - val_loss: 21.9773 - val_mean_absolute_error: 21.6756 - val_mean_squared_error: 520.9788
# Epoch 11/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.9735 - mean_absolute_error: 5.6705 - mean_squared_error: 51.3909Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 23.7421 - mean_absolute_error: 23.4383 - mean_squared_error: 617.4265
# Epoch 00011: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 527ms/step - loss: 5.9832 - mean_absolute_error: 5.6802 - mean_squared_error: 51.3436 - val_loss: 23.7421 - val_mean_absolute_error: 23.4383 - val_mean_squared_error: 617.4265
# Epoch 12/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.9385 - mean_absolute_error: 5.6340 - mean_squared_error: 49.5535Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 25.8674 - mean_absolute_error: 25.5633 - mean_squared_error: 719.7471
# Epoch 00012: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 514ms/step - loss: 5.9873 - mean_absolute_error: 5.6829 - mean_squared_error: 50.4614 - val_loss: 25.8674 - val_mean_absolute_error: 25.5633 - val_mean_squared_error: 719.7471
# Epoch 13/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.4545 - mean_absolute_error: 5.1498 - mean_squared_error: 41.8942Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.4672 - mean_absolute_error: 22.1616 - mean_squared_error: 549.9968
# Epoch 00013: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 516ms/step - loss: 5.4903 - mean_absolute_error: 5.1856 - mean_squared_error: 42.6365 - val_loss: 22.4672 - val_mean_absolute_error: 22.1616 - val_mean_squared_error: 549.9968
# Epoch 14/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.8042 - mean_absolute_error: 5.4983 - mean_squared_error: 48.2026Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 30.3559 - mean_absolute_error: 30.0490 - mean_squared_error: 972.3290
# Epoch 00014: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 530ms/step - loss: 5.7980 - mean_absolute_error: 5.4921 - mean_squared_error: 48.1831 - val_loss: 30.3559 - val_mean_absolute_error: 30.0490 - val_mean_squared_error: 972.3290
# Epoch 15/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.6532 - mean_absolute_error: 5.3460 - mean_squared_error: 43.8366Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 27.5579 - mean_absolute_error: 27.2510 - mean_squared_error: 803.1583
# Epoch 00015: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 523ms/step - loss: 5.6565 - mean_absolute_error: 5.3492 - mean_squared_error: 43.7656 - val_loss: 27.5579 - val_mean_absolute_error: 27.2510 - val_mean_squared_error: 803.1583
# Epoch 16/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.8141 - mean_absolute_error: 5.5074 - mean_squared_error: 46.3161Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 27.8797 - mean_absolute_error: 27.5727 - mean_squared_error: 831.2854
# Epoch 00016: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 516ms/step - loss: 5.8354 - mean_absolute_error: 5.5288 - mean_squared_error: 46.6201 - val_loss: 27.8797 - val_mean_absolute_error: 27.5727 - val_mean_squared_error: 831.2854
# Epoch 17/250
# 102/103 [============================>.] - ETA: 0s - loss: 6.0195 - mean_absolute_error: 5.7121 - mean_squared_error: 50.2498Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 24.3961 - mean_absolute_error: 24.0882 - mean_squared_error: 652.3930
# Epoch 00017: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 531ms/step - loss: 6.0538 - mean_absolute_error: 5.7464 - mean_squared_error: 50.8982 - val_loss: 24.3961 - val_mean_absolute_error: 24.0882 - val_mean_squared_error: 652.3930
# Epoch 18/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.6147 - mean_absolute_error: 5.3064 - mean_squared_error: 49.1294Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 23.0625 - mean_absolute_error: 22.7534 - mean_squared_error: 573.1637
# Epoch 00018: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 5.6299 - mean_absolute_error: 5.3216 - mean_squared_error: 49.2454 - val_loss: 23.0625 - val_mean_absolute_error: 22.7534 - val_mean_squared_error: 573.1637
# Epoch 19/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.6182 - mean_absolute_error: 5.3087 - mean_squared_error: 44.4401Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 26.4422 - mean_absolute_error: 26.1322 - mean_squared_error: 746.9366
# Epoch 00019: val_loss did not improve from 7.38385
# 103/103 [==============================] - 52s 501ms/step - loss: 5.6053 - mean_absolute_error: 5.2958 - mean_squared_error: 44.1994 - val_loss: 26.4422 - val_mean_absolute_error: 26.1322 - val_mean_squared_error: 746.9366
# Epoch 20/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.4648 - mean_absolute_error: 5.1547 - mean_squared_error: 42.0213Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.3391 - mean_absolute_error: 22.0282 - mean_squared_error: 558.7218
# Epoch 00020: val_loss did not improve from 7.38385
# 103/103 [==============================] - 56s 545ms/step - loss: 5.4644 - mean_absolute_error: 5.1543 - mean_squared_error: 42.0573 - val_loss: 22.3391 - val_mean_absolute_error: 22.0282 - val_mean_squared_error: 558.7218
# Epoch 21/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.4601 - mean_absolute_error: 5.1493 - mean_squared_error: 41.8673Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.8219 - mean_absolute_error: 21.5117 - mean_squared_error: 531.5140
# Epoch 00021: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 5.4551 - mean_absolute_error: 5.1443 - mean_squared_error: 41.8069 - val_loss: 21.8219 - val_mean_absolute_error: 21.5117 - val_mean_squared_error: 531.5140
# Epoch 22/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.7005 - mean_absolute_error: 5.3905 - mean_squared_error: 46.5728Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 24.3174 - mean_absolute_error: 24.0067 - mean_squared_error: 635.4046
# Epoch 00022: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 512ms/step - loss: 5.6923 - mean_absolute_error: 5.3822 - mean_squared_error: 46.3783 - val_loss: 24.3174 - val_mean_absolute_error: 24.0067 - val_mean_squared_error: 635.4046
# Epoch 23/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.6102 - mean_absolute_error: 5.2991 - mean_squared_error: 42.5425Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 27.7385 - mean_absolute_error: 27.4270 - mean_squared_error: 816.6339
# Epoch 00023: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 520ms/step - loss: 5.6173 - mean_absolute_error: 5.3062 - mean_squared_error: 42.6687 - val_loss: 27.7385 - val_mean_absolute_error: 27.4270 - val_mean_squared_error: 816.6339
# Epoch 24/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3023 - mean_absolute_error: 4.9906 - mean_squared_error: 40.2245Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 28.9317 - mean_absolute_error: 28.6197 - mean_squared_error: 896.8304- ETA: 22s - loss: 26.0400 - mean_absolute_error: 25.7280 - mean_squared_er - ETA: 15s - loss: 28.1882 - mean_absolute_error: 27.8762 - mean_squared_error
# Epoch 00024: val_loss did not improve from 7.38385
# 103/103 [==============================] - 52s 509ms/step - loss: 5.2837 - mean_absolute_error: 4.9721 - mean_squared_error: 39.9612 - val_loss: 28.9317 - val_mean_absolute_error: 28.6197 - val_mean_squared_error: 896.8304
# Epoch 25/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.5091 - mean_absolute_error: 5.1972 - mean_squared_error: 42.9099Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 29.3302 - mean_absolute_error: 29.0067 - mean_squared_error: 912.4235
# Epoch 00025: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 510ms/step - loss: 5.5309 - mean_absolute_error: 5.2190 - mean_squared_error: 43.2801 - val_loss: 29.3188 - val_mean_absolute_error: 29.0067 - val_mean_squared_error: 912.4235
# Epoch 26/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2983 - mean_absolute_error: 4.9858 - mean_squared_error: 39.7859Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 30.3460 - mean_absolute_error: 30.0324 - mean_squared_error: 976.0439
# Epoch 00026: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 5.2992 - mean_absolute_error: 4.9867 - mean_squared_error: 39.9011 - val_loss: 30.3460 - val_mean_absolute_error: 30.0324 - val_mean_squared_error: 976.0439
# Epoch 27/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2902 - mean_absolute_error: 4.9762 - mean_squared_error: 41.1513Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 23.9461 - mean_absolute_error: 23.6315 - mean_squared_error: 633.1171
# Epoch 00027: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 519ms/step - loss: 5.3117 - mean_absolute_error: 4.9977 - mean_squared_error: 41.3226 - val_loss: 23.9461 - val_mean_absolute_error: 23.6315 - val_mean_squared_error: 633.1171
# Epoch 28/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2119 - mean_absolute_error: 4.8963 - mean_squared_error: 40.3281Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 31.3320 - mean_absolute_error: 30.9973 - mean_squared_error: 1038.8042
# Epoch 00028: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 536ms/step - loss: 5.1911 - mean_absolute_error: 4.8754 - mean_squared_error: 40.0618 - val_loss: 31.3134 - val_mean_absolute_error: 30.9973 - val_mean_squared_error: 1038.8042
# Epoch 29/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2405 - mean_absolute_error: 4.9235 - mean_squared_error: 38.9782Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 24.2102 - mean_absolute_error: 23.8927 - mean_squared_error: 635.2093
# Epoch 00029: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 518ms/step - loss: 5.2217 - mean_absolute_error: 4.9047 - mean_squared_error: 38.7509 - val_loss: 24.2102 - val_mean_absolute_error: 23.8927 - val_mean_squared_error: 635.2093
# Epoch 30/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.5089 - mean_absolute_error: 5.1908 - mean_squared_error: 41.0661Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 22.3246 - mean_absolute_error: 22.0063 - mean_squared_error: 544.4344
# Epoch 00030: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 5.5383 - mean_absolute_error: 5.2202 - mean_squared_error: 41.5667 - val_loss: 22.3246 - val_mean_absolute_error: 22.0063 - val_mean_squared_error: 544.4344
# Epoch 31/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3345 - mean_absolute_error: 5.0155 - mean_squared_error: 42.1591Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 26.3054 - mean_absolute_error: 25.9863 - mean_squared_error: 737.6765
# Epoch 00031: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 5.3814 - mean_absolute_error: 5.0623 - mean_squared_error: 42.8741 - val_loss: 26.3054 - val_mean_absolute_error: 25.9863 - val_mean_squared_error: 737.6765
# Epoch 32/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.5718 - mean_absolute_error: 5.2520 - mean_squared_error: 43.6811Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 26.3869 - mean_absolute_error: 26.0653 - mean_squared_error: 748.3307
# Epoch 00032: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 527ms/step - loss: 5.5445 - mean_absolute_error: 5.2247 - mean_squared_error: 43.3429 - val_loss: 26.3869 - val_mean_absolute_error: 26.0653 - val_mean_squared_error: 748.3307
# Epoch 33/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3673 - mean_absolute_error: 5.0456 - mean_squared_error: 42.0384Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 19.1904 - mean_absolute_error: 18.8689 - mean_squared_error: 414.1417
# Epoch 00033: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 533ms/step - loss: 5.3686 - mean_absolute_error: 5.0470 - mean_squared_error: 42.0378 - val_loss: 19.1904 - val_mean_absolute_error: 18.8689 - val_mean_squared_error: 414.1417
# Epoch 34/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.4646 - mean_absolute_error: 5.1424 - mean_squared_error: 41.4667Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 32.1828 - mean_absolute_error: 31.8588 - mean_squared_error: 1094.7112
# Epoch 00034: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 534ms/step - loss: 5.4393 - mean_absolute_error: 5.1171 - mean_squared_error: 41.1869 - val_loss: 32.1828 - val_mean_absolute_error: 31.8588 - val_mean_squared_error: 1094.7112
# Epoch 35/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.7572 - mean_absolute_error: 5.4324 - mean_squared_error: 45.3878Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 31.5992 - mean_absolute_error: 31.2736 - mean_squared_error: 1046.8458
# Epoch 00035: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 528ms/step - loss: 5.7316 - mean_absolute_error: 5.4069 - mean_squared_error: 45.0454 - val_loss: 31.5992 - val_mean_absolute_error: 31.2736 - val_mean_squared_error: 1046.8458
# Epoch 36/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.8100 - mean_absolute_error: 5.4823 - mean_squared_error: 52.7198Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 25.4098 - mean_absolute_error: 25.0808 - mean_squared_error: 698.1504
# Epoch 00036: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 5.8069 - mean_absolute_error: 5.4792 - mean_squared_error: 52.5457 - val_loss: 25.4098 - val_mean_absolute_error: 25.0808 - val_mean_squared_error: 698.1504
# Epoch 37/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1985 - mean_absolute_error: 4.8690 - mean_squared_error: 40.7964Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.8961 - mean_absolute_error: 21.5659 - mean_squared_error: 535.4268
# Epoch 00037: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 532ms/step - loss: 5.1829 - mean_absolute_error: 4.8534 - mean_squared_error: 40.5455 - val_loss: 21.8961 - val_mean_absolute_error: 21.5659 - val_mean_squared_error: 535.4268
# Epoch 38/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.5766 - mean_absolute_error: 5.2468 - mean_squared_error: 43.2709Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.5504 - mean_absolute_error: 21.2205 - mean_squared_error: 517.3622
# Epoch 00038: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 535ms/step - loss: 5.6159 - mean_absolute_error: 5.2861 - mean_squared_error: 44.0972 - val_loss: 21.5504 - val_mean_absolute_error: 21.2205 - val_mean_squared_error: 517.3622
# Epoch 39/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1441 - mean_absolute_error: 4.8136 - mean_squared_error: 38.0805Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.3427 - mean_absolute_error: 21.0121 - mean_squared_error: 539.7092
# Epoch 00039: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 523ms/step - loss: 5.1644 - mean_absolute_error: 4.8339 - mean_squared_error: 38.5858 - val_loss: 21.3427 - val_mean_absolute_error: 21.0121 - val_mean_squared_error: 539.7092
# Epoch 40/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2817 - mean_absolute_error: 4.9508 - mean_squared_error: 39.0615Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 14.8013 - mean_absolute_error: 14.4700 - mean_squared_error: 289.1074
# Epoch 00040: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 5.3414 - mean_absolute_error: 5.0105 - mean_squared_error: 39.9617 - val_loss: 14.8013 - val_mean_absolute_error: 14.4700 - val_mean_squared_error: 289.1074
# Epoch 41/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3099 - mean_absolute_error: 4.9789 - mean_squared_error: 40.2332Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.1964 - mean_absolute_error: 21.8659 - mean_squared_error: 546.4840
# Epoch 00041: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 524ms/step - loss: 5.3192 - mean_absolute_error: 4.9882 - mean_squared_error: 40.2867 - val_loss: 22.1964 - val_mean_absolute_error: 21.8659 - val_mean_squared_error: 546.4840
# Epoch 42/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3300 - mean_absolute_error: 4.9997 - mean_squared_error: 38.3291Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.1462 - mean_absolute_error: 21.8157 - mean_squared_error: 550.2051
# Epoch 00042: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 517ms/step - loss: 5.3271 - mean_absolute_error: 4.9968 - mean_squared_error: 38.2821 - val_loss: 22.1462 - val_mean_absolute_error: 21.8157 - val_mean_squared_error: 550.2051
# Epoch 43/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.4561 - mean_absolute_error: 5.1252 - mean_squared_error: 42.4356Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 17.0744 - mean_absolute_error: 16.7433 - mean_squared_error: 340.7894
# Epoch 00043: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 5.4533 - mean_absolute_error: 5.1224 - mean_squared_error: 42.4541 - val_loss: 17.0744 - val_mean_absolute_error: 16.7433 - val_mean_squared_error: 340.7894
# Epoch 44/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3356 - mean_absolute_error: 5.0035 - mean_squared_error: 40.0085Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 25.9209 - mean_absolute_error: 25.5878 - mean_squared_error: 726.7565
# Epoch 00044: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 5.3368 - mean_absolute_error: 5.0047 - mean_squared_error: 40.0409 - val_loss: 25.9209 - val_mean_absolute_error: 25.5878 - val_mean_squared_error: 726.7565
# Epoch 45/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3258 - mean_absolute_error: 4.9923 - mean_squared_error: 38.9558Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 20.2671 - mean_absolute_error: 19.9335 - mean_squared_error: 456.7412- ETA: 13s - loss: 20.0499 - mean_absolute_error: 19.7162 - mean_squared_error: 446.
# Epoch 00045: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 527ms/step - loss: 5.3355 - mean_absolute_error: 5.0020 - mean_squared_error: 39.0047 - val_loss: 20.2671 - val_mean_absolute_error: 19.9335 - val_mean_squared_error: 456.7412
# Epoch 46/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1650 - mean_absolute_error: 4.8311 - mean_squared_error: 36.4470Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 17.9657 - mean_absolute_error: 17.6318 - mean_squared_error: 376.7202
# Epoch 00046: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 517ms/step - loss: 5.1651 - mean_absolute_error: 4.8312 - mean_squared_error: 36.3887 - val_loss: 17.9657 - val_mean_absolute_error: 17.6318 - val_mean_squared_error: 376.7202
# Epoch 47/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1054 - mean_absolute_error: 4.7715 - mean_squared_error: 37.3945Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 20.2688 - mean_absolute_error: 19.9350 - mean_squared_error: 465.8159
# Epoch 00047: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 527ms/step - loss: 5.0843 - mean_absolute_error: 4.7503 - mean_squared_error: 37.1228 - val_loss: 20.2688 - val_mean_absolute_error: 19.9350 - val_mean_squared_error: 465.8159
# Epoch 48/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1337 - mean_absolute_error: 4.7998 - mean_squared_error: 35.9307Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.8464 - mean_absolute_error: 21.5124 - mean_squared_error: 532.8893
# Epoch 00048: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 518ms/step - loss: 5.1169 - mean_absolute_error: 4.7829 - mean_squared_error: 35.6914 - val_loss: 21.8464 - val_mean_absolute_error: 21.5124 - val_mean_squared_error: 532.8893
# Epoch 49/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2464 - mean_absolute_error: 4.9120 - mean_squared_error: 40.6775Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 22.1988 - mean_absolute_error: 21.8635 - mean_squared_error: 549.2432
# Epoch 00049: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 520ms/step - loss: 5.2208 - mean_absolute_error: 4.8864 - mean_squared_error: 40.3377 - val_loss: 22.1988 - val_mean_absolute_error: 21.8635 - val_mean_squared_error: 549.2432
# Epoch 50/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1534 - mean_absolute_error: 4.8182 - mean_squared_error: 36.6348Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 16.2367 - mean_absolute_error: 15.9015 - mean_squared_error: 313.7657
# Epoch 00050: val_loss did not improve from 7.38385
# 103/103 [==============================] - 52s 505ms/step - loss: 5.1607 - mean_absolute_error: 4.8255 - mean_squared_error: 36.7702 - val_loss: 16.2367 - val_mean_absolute_error: 15.9015 - val_mean_squared_error: 313.7657
# Epoch 51/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.6208 - mean_absolute_error: 5.2847 - mean_squared_error: 45.5603Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 17.9217 - mean_absolute_error: 17.5844 - mean_squared_error: 367.2622
# Epoch 00051: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 526ms/step - loss: 5.5981 - mean_absolute_error: 5.2620 - mean_squared_error: 45.2619 - val_loss: 17.9217 - val_mean_absolute_error: 17.5844 - val_mean_squared_error: 367.2622
# Epoch 52/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1399 - mean_absolute_error: 4.8022 - mean_squared_error: 36.3070Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 25.3750 - mean_absolute_error: 25.0371 - mean_squared_error: 684.6552
# Epoch 00052: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 5.1380 - mean_absolute_error: 4.8002 - mean_squared_error: 36.2412 - val_loss: 25.3750 - val_mean_absolute_error: 25.0371 - val_mean_squared_error: 684.6552
# Epoch 53/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0560 - mean_absolute_error: 4.7182 - mean_squared_error: 36.4122Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.2646 - mean_absolute_error: 20.9272 - mean_squared_error: 495.4045- ETA: 14s - loss: 20.6646 - mean_absolute_error: 20.3271 - mean_squared_error
# Epoch 00053: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 531ms/step - loss: 5.0752 - mean_absolute_error: 4.7374 - mean_squared_error: 36.8813 - val_loss: 21.2646 - val_mean_absolute_error: 20.9272 - val_mean_squared_error: 495.4045
# Epoch 54/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1028 - mean_absolute_error: 4.7654 - mean_squared_error: 36.6259Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 17.8213 - mean_absolute_error: 17.4838 - mean_squared_error: 361.7910
# Epoch 00054: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 518ms/step - loss: 5.0986 - mean_absolute_error: 4.7612 - mean_squared_error: 36.4612 - val_loss: 17.8213 - val_mean_absolute_error: 17.4838 - val_mean_squared_error: 361.7910
# Epoch 55/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8108 - mean_absolute_error: 4.4736 - mean_squared_error: 33.9230Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 20.2794 - mean_absolute_error: 19.9424 - mean_squared_error: 449.8614
# Epoch 00055: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 532ms/step - loss: 4.7997 - mean_absolute_error: 4.4625 - mean_squared_error: 33.7270 - val_loss: 20.2794 - val_mean_absolute_error: 19.9424 - val_mean_squared_error: 449.8614
# Epoch 56/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0587 - mean_absolute_error: 4.7224 - mean_squared_error: 36.5144Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 21.8480 - mean_absolute_error: 21.5570 - mean_squared_error: 523.5643
# Epoch 00056: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 532ms/step - loss: 5.0528 - mean_absolute_error: 4.7165 - mean_squared_error: 36.3495 - val_loss: 21.8930 - val_mean_absolute_error: 21.5570 - val_mean_squared_error: 523.5643
# Epoch 57/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0524 - mean_absolute_error: 4.7163 - mean_squared_error: 36.9082Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 17.8657 - mean_absolute_error: 17.5294 - mean_squared_error: 366.6196
# Epoch 00057: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 513ms/step - loss: 5.0353 - mean_absolute_error: 4.6993 - mean_squared_error: 36.6509 - val_loss: 17.8657 - val_mean_absolute_error: 17.5294 - val_mean_squared_error: 366.6196
# Epoch 58/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8886 - mean_absolute_error: 4.5517 - mean_squared_error: 34.8099Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 23.0222 - mean_absolute_error: 22.6847 - mean_squared_error: 584.3701
# Epoch 00058: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 518ms/step - loss: 4.8777 - mean_absolute_error: 4.5409 - mean_squared_error: 34.6586 - val_loss: 23.0222 - val_mean_absolute_error: 22.6847 - val_mean_squared_error: 584.3701
# Epoch 59/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9475 - mean_absolute_error: 4.6098 - mean_squared_error: 34.3392Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 20.7867 - mean_absolute_error: 20.4496 - mean_squared_error: 474.5246
# Epoch 00059: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 529ms/step - loss: 4.9228 - mean_absolute_error: 4.5851 - mean_squared_error: 34.0758 - val_loss: 20.7867 - val_mean_absolute_error: 20.4496 - val_mean_squared_error: 474.5246
# Epoch 60/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1868 - mean_absolute_error: 4.8497 - mean_squared_error: 36.2453Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 19.5067 - mean_absolute_error: 19.1695 - mean_squared_error: 424.1294
# Epoch 00060: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 536ms/step - loss: 5.1982 - mean_absolute_error: 4.8611 - mean_squared_error: 36.4198 - val_loss: 19.5067 - val_mean_absolute_error: 19.1695 - val_mean_squared_error: 424.1294
# Epoch 61/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1032 - mean_absolute_error: 4.7648 - mean_squared_error: 34.3759Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.1756 - mean_absolute_error: 21.7967 - mean_squared_error: 537.8523
# Epoch 00061: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 5.0964 - mean_absolute_error: 4.7580 - mean_squared_error: 34.3002 - val_loss: 22.1359 - val_mean_absolute_error: 21.7967 - val_mean_squared_error: 537.8523
# Epoch 62/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.3821 - mean_absolute_error: 5.0428 - mean_squared_error: 39.8960Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 20.8503 - mean_absolute_error: 20.5112 - mean_squared_error: 490.5630
# Epoch 00062: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 5.3960 - mean_absolute_error: 5.0567 - mean_squared_error: 39.9759 - val_loss: 20.8503 - val_mean_absolute_error: 20.5112 - val_mean_squared_error: 490.5630
# Epoch 63/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9166 - mean_absolute_error: 4.5775 - mean_squared_error: 33.1495  ETA: 20s - loss:Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 23.9413 - mean_absolute_error: 23.6537 - mean_squared_error: 642.2018
# Epoch 00063: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 533ms/step - loss: 4.9185 - mean_absolute_error: 4.5794 - mean_squared_error: 33.2008 - val_loss: 23.9931 - val_mean_absolute_error: 23.6537 - val_mean_squared_error: 642.2018
# Epoch 64/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0660 - mean_absolute_error: 4.7267 - mean_squared_error: 37.6907Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 23.8831 - mean_absolute_error: 23.5434 - mean_squared_error: 631.3486
# Epoch 00064: val_loss did not improve from 7.38385
# 103/103 [==============================] - 51s 494ms/step - loss: 5.0509 - mean_absolute_error: 4.7115 - mean_squared_error: 37.4834 - val_loss: 23.8831 - val_mean_absolute_error: 23.5434 - val_mean_squared_error: 631.3486
# Epoch 65/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8675 - mean_absolute_error: 4.5274 - mean_squared_error: 32.2286Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 17.3519 - mean_absolute_error: 17.0114 - mean_squared_error: 355.4220
# Epoch 00065: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 527ms/step - loss: 4.8596 - mean_absolute_error: 4.5195 - mean_squared_error: 32.1648 - val_loss: 17.3519 - val_mean_absolute_error: 17.0114 - val_mean_squared_error: 355.4220
# Epoch 66/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0000 - mean_absolute_error: 4.6593 - mean_squared_error: 36.9082Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 18.4010 - mean_absolute_error: 18.0604 - mean_squared_error: 386.1835
# Epoch 00066: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 4.9937 - mean_absolute_error: 4.6530 - mean_squared_error: 36.7258 - val_loss: 18.4010 - val_mean_absolute_error: 18.0604 - val_mean_squared_error: 386.1835
# Epoch 67/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0143 - mean_absolute_error: 4.6723 - mean_squared_error: 34.2645Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 16.4233 - mean_absolute_error: 16.0809 - mean_squared_error: 323.0996- ETA: 20s - loss: 14.8823 - mean_absolute_error: 14.5400 - mean_s
# Epoch 00067: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 530ms/step - loss: 5.0151 - mean_absolute_error: 4.6732 - mean_squared_error: 34.2092 - val_loss: 16.4233 - val_mean_absolute_error: 16.0809 - val_mean_squared_error: 323.0996
# Epoch 68/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9843 - mean_absolute_error: 4.6416 - mean_squared_error: 35.3658Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 15.9812 - mean_absolute_error: 15.6383 - mean_squared_error: 310.0912
# Epoch 00068: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 518ms/step - loss: 4.9799 - mean_absolute_error: 4.6373 - mean_squared_error: 35.2141 - val_loss: 15.9812 - val_mean_absolute_error: 15.6383 - val_mean_squared_error: 310.0912
# Epoch 69/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9738 - mean_absolute_error: 4.6309 - mean_squared_error: 34.5570Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 26.4776 - mean_absolute_error: 26.1344 - mean_squared_error: 753.8726
# Epoch 00069: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 516ms/step - loss: 4.9751 - mean_absolute_error: 4.6322 - mean_squared_error: 34.5553 - val_loss: 26.4776 - val_mean_absolute_error: 26.1344 - val_mean_squared_error: 753.8726
# Epoch 70/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0997 - mean_absolute_error: 4.7565 - mean_squared_error: 35.8797Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 23.0167 - mean_absolute_error: 22.6731 - mean_squared_error: 594.9614
# Epoch 00070: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 520ms/step - loss: 5.1004 - mean_absolute_error: 4.7572 - mean_squared_error: 35.8168 - val_loss: 23.0167 - val_mean_absolute_error: 22.6731 - val_mean_squared_error: 594.9614
# Epoch 71/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8833 - mean_absolute_error: 4.5391 - mean_squared_error: 31.8826Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 23.1381 - mean_absolute_error: 22.7934 - mean_squared_error: 595.6894
# Epoch 00071: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 523ms/step - loss: 4.8742 - mean_absolute_error: 4.5301 - mean_squared_error: 31.7032 - val_loss: 23.1381 - val_mean_absolute_error: 22.7934 - val_mean_squared_error: 595.6894
# Epoch 72/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1439 - mean_absolute_error: 4.7991 - mean_squared_error: 36.0685Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 13.3540 - mean_absolute_error: 13.0094 - mean_squared_error: 233.9446
# Epoch 00072: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 530ms/step - loss: 5.1549 - mean_absolute_error: 4.8101 - mean_squared_error: 36.2998 - val_loss: 13.3540 - val_mean_absolute_error: 13.0094 - val_mean_squared_error: 233.9446
# Epoch 73/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7029 - mean_absolute_error: 4.3577 - mean_squared_error: 32.2073Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 17.7872 - mean_absolute_error: 17.4416 - mean_squared_error: 373.3832
# Epoch 00073: val_loss did not improve from 7.38385
# 103/103 [==============================] - 52s 509ms/step - loss: 4.7394 - mean_absolute_error: 4.3942 - mean_squared_error: 32.5978 - val_loss: 17.7872 - val_mean_absolute_error: 17.4416 - val_mean_squared_error: 373.3832
# Epoch 74/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1304 - mean_absolute_error: 4.7835 - mean_squared_error: 37.1476Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 15.2063 - mean_absolute_error: 14.8577 - mean_squared_error: 307.5553
# Epoch 00074: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 528ms/step - loss: 5.1449 - mean_absolute_error: 4.7979 - mean_squared_error: 37.2198 - val_loss: 15.2063 - val_mean_absolute_error: 14.8577 - val_mean_squared_error: 307.5553
# Epoch 75/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7696 - mean_absolute_error: 4.4203 - mean_squared_error: 30.7999Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 23.1308 - mean_absolute_error: 22.7811 - mean_squared_error: 594.5644
# Epoch 00075: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 518ms/step - loss: 4.7502 - mean_absolute_error: 4.4009 - mean_squared_error: 30.5808 - val_loss: 23.1308 - val_mean_absolute_error: 22.7811 - val_mean_squared_error: 594.5644
# Epoch 76/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9819 - mean_absolute_error: 4.6323 - mean_squared_error: 34.2877Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 16.4864 - mean_absolute_error: 16.1370 - mean_squared_error: 321.6553
# Epoch 00076: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 528ms/step - loss: 4.9629 - mean_absolute_error: 4.6133 - mean_squared_error: 34.0746 - val_loss: 16.4864 - val_mean_absolute_error: 16.1370 - val_mean_squared_error: 321.6553
# Epoch 77/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7004 - mean_absolute_error: 4.3508 - mean_squared_error: 33.0619Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 16.8088 - mean_absolute_error: 16.4594 - mean_squared_error: 345.5746
# Epoch 00077: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 530ms/step - loss: 4.6844 - mean_absolute_error: 4.3349 - mean_squared_error: 32.8236 - val_loss: 16.8088 - val_mean_absolute_error: 16.4594 - val_mean_squared_error: 345.5746
# Epoch 78/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0157 - mean_absolute_error: 4.6662 - mean_squared_error: 35.1976Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 20.6235 - mean_absolute_error: 20.2742 - mean_squared_error: 489.6658
# Epoch 00078: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 516ms/step - loss: 5.0329 - mean_absolute_error: 4.6834 - mean_squared_error: 35.2696 - val_loss: 20.6235 - val_mean_absolute_error: 20.2742 - val_mean_squared_error: 489.6658
# Epoch 79/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0960 - mean_absolute_error: 4.7464 - mean_squared_error: 36.2027Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 26.2202 - mean_absolute_error: 25.8704 - mean_squared_error: 739.0088
# Epoch 00079: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 536ms/step - loss: 5.1058 - mean_absolute_error: 4.7562 - mean_squared_error: 36.3415 - val_loss: 26.2202 - val_mean_absolute_error: 25.8704 - val_mean_squared_error: 739.0088
# Epoch 80/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7730 - mean_absolute_error: 4.4234 - mean_squared_error: 30.1494Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 21.9525 - mean_absolute_error: 21.6032 - mean_squared_error: 532.3611
# Epoch 00080: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 520ms/step - loss: 4.7719 - mean_absolute_error: 4.4223 - mean_squared_error: 30.0872 - val_loss: 21.9525 - val_mean_absolute_error: 21.6032 - val_mean_squared_error: 532.3611
# Epoch 81/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0388 - mean_absolute_error: 4.6897 - mean_squared_error: 35.0649Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 21.5775 - mean_absolute_error: 21.2282 - mean_squared_error: 517.6144
# Epoch 00081: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 5.0483 - mean_absolute_error: 4.6992 - mean_squared_error: 35.2208 - val_loss: 21.5775 - val_mean_absolute_error: 21.2282 - val_mean_squared_error: 517.6144
# Epoch 82/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9605 - mean_absolute_error: 4.6115 - mean_squared_error: 33.9842Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 19.8080 - mean_absolute_error: 19.4591 - mean_squared_error: 451.2586
# Epoch 00082: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 533ms/step - loss: 4.9569 - mean_absolute_error: 4.6079 - mean_squared_error: 33.9590 - val_loss: 19.8080 - val_mean_absolute_error: 19.4591 - val_mean_squared_error: 451.2586
# Epoch 83/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8615 - mean_absolute_error: 4.5119 - mean_squared_error: 33.6123Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.8906 - mean_absolute_error: 22.5394 - mean_squared_error: 579.2178
# Epoch 00083: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 4.8409 - mean_absolute_error: 4.4912 - mean_squared_error: 33.3759 - val_loss: 22.8906 - val_mean_absolute_error: 22.5394 - val_mean_squared_error: 579.2178
# Epoch 84/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8856 - mean_absolute_error: 4.5347 - mean_squared_error: 31.5198Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 19.4305 - mean_absolute_error: 19.0798 - mean_squared_error: 429.2402
# Epoch 00084: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 4.8948 - mean_absolute_error: 4.5438 - mean_squared_error: 31.6450 - val_loss: 19.4305 - val_mean_absolute_error: 19.0798 - val_mean_squared_error: 429.2402
# Epoch 85/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2358 - mean_absolute_error: 4.8852 - mean_squared_error: 38.3297Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 20.2497 - mean_absolute_error: 19.8992 - mean_squared_error: 467.3110
# Epoch 00085: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 530ms/step - loss: 5.2422 - mean_absolute_error: 4.8916 - mean_squared_error: 38.3579 - val_loss: 20.2497 - val_mean_absolute_error: 19.8992 - val_mean_squared_error: 467.3110
# Epoch 86/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.5233 - mean_absolute_error: 4.1729 - mean_squared_error: 27.9786Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 18.0381 - mean_absolute_error: 17.7035 - mean_squared_error: 384.5424
# Epoch 00086: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 514ms/step - loss: 4.5139 - mean_absolute_error: 4.1635 - mean_squared_error: 27.9013 - val_loss: 18.0536 - val_mean_absolute_error: 17.7035 - val_mean_squared_error: 384.5424
# Epoch 87/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.1295 - mean_absolute_error: 4.7789 - mean_squared_error: 35.9040Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 20.2138 - mean_absolute_error: 19.8626 - mean_squared_error: 456.9749
# Epoch 00087: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 5.1319 - mean_absolute_error: 4.7813 - mean_squared_error: 35.8735 - val_loss: 20.2138 - val_mean_absolute_error: 19.8626 - val_mean_squared_error: 456.9749
# Epoch 88/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.0616 - mean_absolute_error: 4.7101 - mean_squared_error: 35.9485Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 23.1641 - mean_absolute_error: 22.8124 - mean_squared_error: 598.6500
# Epoch 00088: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 523ms/step - loss: 5.0694 - mean_absolute_error: 4.7180 - mean_squared_error: 35.9067 - val_loss: 23.1641 - val_mean_absolute_error: 22.8124 - val_mean_squared_error: 598.6500
# Epoch 89/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.6587 - mean_absolute_error: 4.3070 - mean_squared_error: 30.1701Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.9482 - mean_absolute_error: 22.5965 - mean_squared_error: 585.1481
# Epoch 00089: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 520ms/step - loss: 4.6687 - mean_absolute_error: 4.3169 - mean_squared_error: 30.2693 - val_loss: 22.9482 - val_mean_absolute_error: 22.5965 - val_mean_squared_error: 585.1481
# Epoch 90/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9348 - mean_absolute_error: 4.5834 - mean_squared_error: 33.7819Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 20.2709 - mean_absolute_error: 19.9196 - mean_squared_error: 456.4725
# Epoch 00090: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 530ms/step - loss: 4.9494 - mean_absolute_error: 4.5980 - mean_squared_error: 34.1264 - val_loss: 20.2709 - val_mean_absolute_error: 19.9196 - val_mean_squared_error: 456.4725
# Epoch 91/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8910 - mean_absolute_error: 4.5398 - mean_squared_error: 33.9113Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 20.0564 - mean_absolute_error: 19.7051 - mean_squared_error: 446.0283
# Epoch 00091: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 521ms/step - loss: 4.8791 - mean_absolute_error: 4.5279 - mean_squared_error: 33.6928 - val_loss: 20.0564 - val_mean_absolute_error: 19.7051 - val_mean_squared_error: 446.0283
# Epoch 92/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7828 - mean_absolute_error: 4.4305 - mean_squared_error: 31.5499Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 18.1767 - mean_absolute_error: 17.7812 - mean_squared_error: 377.1518
# Epoch 00092: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 531ms/step - loss: 4.7849 - mean_absolute_error: 4.4326 - mean_squared_error: 31.6526 - val_loss: 18.1336 - val_mean_absolute_error: 17.7812 - val_mean_squared_error: 377.1518
# Epoch 93/250
# 102/103 [============================>.] - ETA: 0s - loss: 5.2766 - mean_absolute_error: 4.9244 - mean_squared_error: 38.2736Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 18.3691 - mean_absolute_error: 18.0174 - mean_squared_error: 382.5137
# Epoch 00093: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 529ms/step - loss: 5.2694 - mean_absolute_error: 4.9172 - mean_squared_error: 38.0879 - val_loss: 18.3691 - val_mean_absolute_error: 18.0174 - val_mean_squared_error: 382.5137
# Epoch 94/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.5226 - mean_absolute_error: 4.1711 - mean_squared_error: 27.3758- ETA: 4s - loss: 4.4962 - mean_absolute_error: 4.1447 - mean_squared_error:Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 23.6861 - mean_absolute_error: 23.3349 - mean_squared_error: 601.0956
# Epoch 00094: val_loss did not improve from 7.38385
# 103/103 [==============================] - 53s 519ms/step - loss: 4.5163 - mean_absolute_error: 4.1648 - mean_squared_error: 27.2556 - val_loss: 23.6861 - val_mean_absolute_error: 23.3349 - val_mean_squared_error: 601.0956
# Epoch 95/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.6786 - mean_absolute_error: 4.3275 - mean_squared_error: 30.1692Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 22.2705 - mean_absolute_error: 21.9196 - mean_squared_error: 550.1344
# Epoch 00095: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 522ms/step - loss: 4.7036 - mean_absolute_error: 4.3526 - mean_squared_error: 30.4620 - val_loss: 22.2705 - val_mean_absolute_error: 21.9196 - val_mean_squared_error: 550.1344
# Epoch 96/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9757 - mean_absolute_error: 4.6241 - mean_squared_error: 33.9642Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 23.5496 - mean_absolute_error: 23.1974 - mean_squared_error: 608.0774
# Epoch 00096: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 525ms/step - loss: 4.9675 - mean_absolute_error: 4.6159 - mean_squared_error: 33.7980 - val_loss: 23.5496 - val_mean_absolute_error: 23.1974 - val_mean_squared_error: 608.0774
# Epoch 97/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.5057 - mean_absolute_error: 4.1531 - mean_squared_error: 27.7721Epoch 1/250
#  26/103 [======>.......................] - ETA: 12s - loss: 27.5426 - mean_absolute_error: 27.1899 - mean_squared_error: 810.7022
# Epoch 00097: val_loss did not improve from 7.38385
# 103/103 [==============================] - 57s 549ms/step - loss: 4.4819 - mean_absolute_error: 4.1293 - mean_squared_error: 27.5313 - val_loss: 27.5426 - val_mean_absolute_error: 27.1899 - val_mean_squared_error: 810.7022
# Epoch 98/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7611 - mean_absolute_error: 4.4081 - mean_squared_error: 30.8854Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 20.8703 - mean_absolute_error: 20.5169 - mean_squared_error: 486.1149
# Epoch 00098: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 533ms/step - loss: 4.7613 - mean_absolute_error: 4.4083 - mean_squared_error: 30.8690 - val_loss: 20.8703 - val_mean_absolute_error: 20.5169 - val_mean_squared_error: 486.1149
# Epoch 99/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.7703 - mean_absolute_error: 4.4166 - mean_squared_error: 31.5899Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 18.1446 - mean_absolute_error: 17.7906 - mean_squared_error: 371.5640
# Epoch 00099: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 526ms/step - loss: 4.7605 - mean_absolute_error: 4.4067 - mean_squared_error: 31.4396 - val_loss: 18.1446 - val_mean_absolute_error: 17.7906 - val_mean_squared_error: 371.5640
# Epoch 100/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.8184 - mean_absolute_error: 4.4646 - mean_squared_error: 32.2934Epoch 1/250
#  26/103 [======>.......................] - ETA: 14s - loss: 14.5032 - mean_absolute_error: 14.1499 - mean_squared_error: 263.7567
# Epoch 00100: val_loss did not improve from 7.38385
# 103/103 [==============================] - 55s 532ms/step - loss: 4.8427 - mean_absolute_error: 4.4890 - mean_squared_error: 32.6867 - val_loss: 14.5032 - val_mean_absolute_error: 14.1499 - val_mean_squared_error: 263.7567
# Epoch 101/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.6683 - mean_absolute_error: 4.3141 - mean_squared_error: 31.3415Epoch 1/250
#  26/103 [======>.......................] - ETA: 13s - loss: 17.4016 - mean_absolute_error: 17.0461 - mean_squared_error: 355.4102- ETA: 23s - loss: 16.0317 - mean_absolute_error: 15.6762 - mean
# Epoch 00101: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 524ms/step - loss: 4.6831 - mean_absolute_error: 4.3289 - mean_squared_error: 31.6600 - val_loss: 17.4016 - val_mean_absolute_error: 17.0461 - val_mean_squared_error: 355.4102
# Epoch 102/250
# 102/103 [============================>.] - ETA: 0s - loss: 4.9589 - mean_absolute_error: 4.6036 - mean_squared_error: 34.3015Epoch 1/250
#  26/103 [======>.......................] - ETA: 11s - loss: 25.0596 - mean_absolute_error: 24.7046 - mean_squared_error: 684.1604
# Epoch 00102: val_loss did not improve from 7.38385
# 103/103 [==============================] - 54s 523ms/step - loss: 4.9497 - mean_absolute_error: 4.5945 - mean_squared_error: 34.1475 - val_loss: 25.0596 - val_mean_absolute_error: 24.7046 - val_mean_squared_error: 684.1604
# Epoch 00102: early stopping

# %%
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('ResNet IXI Transfer Learning Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

plt.show()

plt.plot(h.history['mean_absolute_error'])
plt.plot(h.history['val_mean_absolute_error'])
plt.title('ResNet Transfer Learning MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

plt.show()

# %%
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('ResNet IXI Transfer Learning Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

plt.show()

plt.plot(h.history['mean_absolute_error'])
plt.plot(h.history['val_mean_absolute_error'])
plt.title('ResNet Transfer Learning MAE')
plt.ylabel('MAE')
plt.xlabel('Epoch')
plt.legend(['Train', 'Valid'], loc='upper left')

plt.show()

# %%
model = load_model('../Models/BrainAgeResNet({}-Ice)'.format(imageType))

ixi_val_prediction_noTL = model.predict(dataGenerator([val_IXI.Loc.values,val_IXI.Scanner.values,val_IXI.Gender.values],val_IXI.Age.values, batch_size = 1, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        )

predictions = ixi_val_prediction_noTL[:,0]
yVal = val_IXI.Age.values
print('Validation R^2: ',r2_score(yVal,predictions))
print('Validation MAE: ',mean_absolute_error(yVal,predictions))
y_range = np.arange(np.min(yVal),np.max(yVal))
plt.scatter(yVal,predictions,label='T1 Prediction')
plt.plot(y_range,y_range,c='black',ls='dashed',label='45 deg line')
plt.xlabel('Age')
plt.ylabel('Predicted Age')
plt.title('Prediction without transfer learning (IXI Validation)')
plt.legend()
plt.show()

model = load_model('../Models/BrainAgeResNet({}-Ice-TransferLearningOnIXI)'.format(imageType))

ixi_val_prediction_TL = model.predict(dataGenerator([val_IXI.Loc.values,val_IXI.Scanner.values,val_IXI.Gender.values],val_IXI.Age.values, batch_size = 1, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        )

predictions = ixi_val_prediction_TL[:,0]
yVal = val_IXI.Age.values
print('Validation R^2: ',r2_score(yVal,predictions))
print('Validation MAE: ',mean_absolute_error(yVal,predictions))
y_range = np.arange(np.min(yVal),np.max(yVal))
plt.scatter(yVal,predictions,label='T1 Prediction')
plt.plot(y_range,y_range,c='black',ls='dashed',label='45 deg line')
plt.xlabel('Age')
plt.ylabel('Predicted Age')
plt.title('Prediction with transfer learning (IXI Validation)')
plt.legend()
plt.show()
# Out:
# 104/104 [==============================] - 4s 38ms/step
# Validation R^2:  0.7398874166869513
# Validation MAE:  6.991243881812462
# 104/104 [==============================] - 4s 38ms/step
# Validation R^2:  0.7145772092864744
# Validation MAE:  7.089926260434664

# %% [markdown]
# #### UK Biobank brian age prediction

# %%
ukb = getUKBData(imageType)

# %%
batchExample = dataGenerator([ukb.Loc.values,ukb.Scanner.values,ukb.Gender.values],ukb.Age.values, batch_size = 4, meanImg=None,dim=dataShape,shuffle=False,augment=False,maxAngle=40,maxShift=10)
tmp = batchExample.__getitem__(70)
print('Age: {} years'.format(tmp[1][0][0]))
plotData(tmp[0][0][:,:,:,:,:],c=2,d=10,nSlices=8)
# Out:
# Age: 70.051 years

# %% [markdown]
# Let's predict the age of the UK Biobank data using the ResNet trained on the Icelandic data only.

# %%
model = load_model('../Models/BrainAgeResNet({}-Ice)'.format(imageType))

# %%
ukb_prediction_noTL = model.predict(dataGenerator([ukb.Loc.values,ukb.Scanner.values,ukb.Gender.values],ukb.Age.values, batch_size = 1, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        )
# Out:
# 19642/19642 [==============================] - 643s 33ms/step

# %%
predictions = ukb_prediction_noTL[:,0]
y = ukb.Age.values 
print('R^2: ',r2_score(y,predictions))
print('MAE: ',mean_absolute_error(y,predictions))
plt.scatter(y,predictions,label='Predictions')
y_range = np.arange(20,np.max(y))
plt.plot(y_range,y_range,c='black',ls='dashed',label='45 deg line')
plt.xlabel('Age')
plt.ylabel('Predicted Age')
plt.title('Prediction without transfer learning (UK Biobank)')
plt.legend()
plt.show()
# Out:
# R^2:  -0.701379881145578
# MAE:  8.59772185961878

# %%
brainAge = pd.DataFrame({'PredictedBrainAge':np.array(predictions)},index = ukb['ID'])
brainAge.to_csv('../Results/{}_CNN_NoTL_pred.txt'.format(imageType),sep='\t')

# %% [markdown]
# Now let's try the model trained on the Icelandic data and IXI.

# %%
model = load_model('../Models/BrainAgeResNet({}-Ice-TransferLearningOnIXI)'.format(imageType))

# %%
ukb_prediction_TL = model.predict(dataGenerator([ukb.Loc.values,ukb.Scanner.values,ukb.Gender.values],ukb.Age.values, batch_size = 1, meanImg=meanImg,dim=dataShape,shuffle=False,augment=False),
                        verbose=1,
                        max_queue_size=32,
                        workers=4,
                        use_multiprocessing=False,
                        )

predictions = ukb_prediction_TL[:,0]
y = ukb.Age.values 
print('R^2: ',r2_score(y,predictions))
print('MAE: ',mean_absolute_error(y,predictions))

plt.scatter(y,predictions,label='Predictions')
y_range = np.arange(20,np.max(y))
plt.plot(y_range,y_range,c='black',ls='dashed',label='45 deg line')
plt.xlabel('Age')
plt.ylabel('Predicted Age')
plt.title('Prediction with transfer learning (UK Biobank)')
plt.legend()
plt.show()
# Out:
# 19642/19642 [==============================] - 636s 32ms/step
# R^2:  0.4172617750147054
# MAE:  4.586766158826117

# %%
brainAge = pd.DataFrame({'PredictedBrainAge':np.array(predictions)},index = ukb['ID'])
brainAge.to_csv('../Results/{}_CNN_WithTL_pred.txt'.format(imageType),sep='\t')
